# %% [markdown]
# # Nbextensions

# %% [markdown]
# ## Markdown live preview

# %% [markdown]
# <span style="background-color: #FFFF00">With this Snippet we can prewiew the output of the markdown cells<span>

# %% [markdown]
# ### Bigger Title
# #### Smaller Title
#
# Text: **bold** and *italics*
#
# A list:
# * Hello
# * Bye Bye
#
# <span style="color:blue">Blue text in html<span>

# %% [markdown]
# ## Snippets

# %% [markdown]
# <span style="background-color: #FFFF00">Prebuild of customized code that can be reutilized</span>

# %%
#Snippet importar pandas
import pandas as pd
import numpy as np

# %%
#Snippet importar matplotlib
from __future__ import print_function, division
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Conditional list comprehension
[x**2 for x in range(-10, 11) if (x%3)==0]
# Out:
# [81, 36, 9, 0, 9, 36, 81]

# %%
# Name dataset as data

data = np.array([1.2, 3.4, 5.6])

# %%
# Viz
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Silly example data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Make the plot
fig = plt.figure()
ax = fig.gca(projection="3d")
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# /var/folders/y8/ypjvwqqx09s0szf2lsykq5vh0000gn/T/ipykernel_1640/1818395658.py:14: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")

# %% [markdown]
# ## Codefolding

# %% [markdown]
# <span style="background-color: #FFFF00">Grouping parts of the code under the same level of indentation</span>

# %%
def factorial(num):
    if num==1:
        return 1
    else:
        return num * factorial(num-1)

def add(a,b):
    return a+b

def multiply(a,b):
    return a*b

# %% [markdown]
# ## Executiontime

# %% [markdown]
# <span style="background-color: #FFFF00">Execution time of each cell and the las date of execution</span>

# %%
factorial(2)
# Out:
# 2

# %%
factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %% [markdown]
# ## Variable Inspector

# %% [markdown]
# <span style="background-color: #FFFF00">Check the value and state of each variable being used on the notebook</span>

# %%
a = 1

# %%
b = 2

# %%
c = a + b

# %% [markdown]
# ## Table of contents

# %% [markdown]
# <span style="background-color: #FFFF00">The nbextension have a Table of Contents on the sidebar or on the first Cell</span>
